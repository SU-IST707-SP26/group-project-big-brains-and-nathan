# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('merged.csv')
data
# Out:
#        Unnamed: 0  player_id                name_x position_x  \
# 0               0     100009        Johnny Jackson         WR
# 1               1     102597           Will Rogers         QB
# 2               2     107494          Trey Sanders         RB
# 3               3     109907               Jon Lee         RB
# 4               4     136429  Cedric Patterson III         WR
# ...           ...        ...                   ...        ...
# 12403       12403    5298407      Mitchell Summers         RB
# 12404       12404    5298427           DJ Williams         RB
# 12405       12405    5302266         Donovan Brown         WR
# 12406       12406    5303173       Galamama Mulbah         RB
# 12407       12407    5306715             Dj Jordan         WR
#
#                 team_x  season_x conference  usage_passing_downs  \
# 0              Arizona      2015        PAC             0.104000
# 1           Washington      2024        B1G             0.670000
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0     player_id      season_x  usage_passing_downs  \
# count  12408.000000  1.240800e+04  12408.000000         12408.000000
# mean    6203.500000  3.743316e+06   2020.507012             0.101776
# std     3582.025405  1.589850e+06      3.743395             0.139283
# min        0.000000  1.000090e+05   2014.000000             0.000000
# 25%     3101.750000  3.843570e+06   2017.000000             0.033000
# 50%     6203.500000  4.362474e+06   2021.000000             0.059333
# 75%     9305.250000  4.714104e+06   2024.000000             0.100667
# max    12407.000000  5.306715e+06   2025.000000             1.000000
#
#        usage_standard_downs  usage_third_down  usage_second_down  \
# count          12408.000000      12408.000000       12408.000000
# mean               0.088204          0.102434           0.093639
# std                0.104872          0.144543           0.113626
# min                0.000000          0.000000           0.000000
# ...

# %%
nfl = data[data['pick'].notnull()]
nfl
# Out:
#        Unnamed: 0  player_id          name_x position_x         team_x  \
# 10             10     246044   Tyler Johnson         WR      Minnesota
# 13             13     480211    Andre Debose         WR        Florida
# 15             15     480746     Bryce Petty         QB         Baylor
# 37             37     500253  Randall Telfer         TE            USC
# 45             45     500419  Trevor Siemian         QB   Northwestern
# ...           ...        ...             ...        ...            ...
# 10096       10096    4911851   Lequint Allen         RB       Syracuse
# 10554       10554    5081397   Dylan Sampson         RB      Tennessee
# 10645       10645    5082630    Jalen Royals         WR     Utah State
# 10661       10661    5083076   Harold Fannin         TE  Bowling Green
# 11077       11077    5123663    Isaac Teslaa         WR       Arkansas
#
#        season_x conference  usage_passing_downs  usage_standard_downs  \
# ...

# %%
positions = data['position_x'].value_counts().sort_values()
nfl_positions = nfl['position_x'].value_counts().sort_values()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

positions.plot(kind = 'barh', ax = ax1)
ax1.set_title('NCAA Distribution of Positions')
ax1.set_xlabel('Number of Players')
ax1.set_ylabel('Position')

nfl_positions.plot(kind = 'barh', ax = ax2)
ax2.set_title('NFL Drafted Distribution of Positions')
ax2.set_xlabel('Number of Players')
ax2.set_ylabel('Position')
plt.show()

# %%
positions = data['conference'].value_counts().sort_values()
nfl_positions = nfl['conference'].value_counts().sort_values()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

positions.plot(kind = 'barh', ax = ax1)
ax1.set_title('Total NCAA Conference Distribution')
ax1.set_xlabel('Number of Players')
ax1.set_ylabel('Position')

nfl_positions.plot(kind = 'barh', ax = ax2)
ax2.set_title('NFL Drafted Conference Distribution')
ax2.set_xlabel('Number of Players')
ax2.set_ylabel('Position')
plt.show()

# %%
#top 15 teams by player count
positions = data['team_x'].value_counts().head(15).sort_values()
nfl_positions = nfl['team_x'].value_counts().head(15).sort_values()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

positions.plot(kind = 'barh', ax = ax1)
ax1.set_title('Total NCAA Top 15 Teams by Amount of Players')
ax1.set_xlabel('Number of Players')
ax1.set_ylabel('Conference')

nfl_positions.plot(kind = 'barh', ax = ax2)
ax2.set_title('NFL Drafted Top 15 Teams by Amount of Players')
ax2.set_xlabel('Number of Players')
ax2.set_ylabel('Conference')
plt.show()

# %%
#season distribution
plt.hist(data['height'])
plt.title('Age Distribution of Drafted Players')
plt.xlabel('Height (Inches)')
plt.ylabel('Number of Players')
plt.show()

# %%
#age distribution - lot of NAs due to being NFL data
plt.hist(data['age'])
plt.title('Age Distribution of Drafted Players')
plt.xlabel('Age')
plt.ylabel('Number of Players')
plt.show()

# %%
#usage rate distribution 
plt.hist(data['usage_overall'])
plt.title('Usage Distribution of Players')
plt.xlabel('Usage Rate')
plt.ylabel('Number of Players')
plt.show()

# %%
#total ppa distribution 
plt.hist(data['total_ppa_all'])
plt.title('PPA Distribution of Players')
plt.xlabel('Total PPA')
plt.ylabel('Number of Players')
plt.show()

# %%
#Distribution of Passing TDs by QB
qbs = data[data['position_x'] == 'QB']

plt.hist(qbs['passing_TD'])
plt.title('Passing TD Distribution')
plt.xlabel('Total Passing TDs')
plt.ylabel('Number of Players')
plt.show()

# %%
#QBs passing TD vs rushing TD

plt.scatter(qbs['passing_TD'], qbs['rushing_TD'])
plt.title('Quarterbacks: Passing TDs vs. Rushing TDs')
plt.xlabel('Total Passing TDs')
plt.ylabel('Total Rushing TDs')
plt.show()

# %%
rbs = data[data['position_x'] == 'RB']

plt.scatter(qbs['rushing_TD'], qbs['receiving_TD'])
plt.title('Runningbacks: Rushing TDs vs. Receiving TDs')
plt.xlabel('Total Rushing TDs')
plt.ylabel('Total Receiving TDs')
plt.show()
